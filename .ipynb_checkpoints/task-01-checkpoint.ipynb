# %% [markdown]
# ### Task 01

# %%
# !pip install numpy matplotlib pandas seaborn
# Out:
# Requirement already satisfied: numpy in /home/dasunwickr/miniconda3/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: matplotlib in /home/dasunwickr/miniconda3/lib/python3.13/site-packages (3.10.5)
# Collecting pandas
#   Downloading pandas-2.3.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dasunwickr/miniconda3/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/dasunwickr/miniconda3/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dasunwickr/miniconda3/lib/python3.13/site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/dasunwickr/miniconda3/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/dasunwickr/miniconda3/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/dasunwickr/miniconda3/lib/python3.13/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/dasunwickr/miniconda3/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/dasunwickr/miniconda3/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/dasunwickr/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading pandas-2.3.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 101.2 kB/s eta 0:00:000:00:0336m0:00:06:14
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [seaborn]━━━ 3/4 [seaborn]
# Successfully installed pandas-2.3.1 pytz-2025.2 seaborn-0.13.2 tzdata-2025.2

# %% [markdown]
# 1. Create a random 4x4 array from an exponential distribution.

# %%
import numpy as np

# %%
np.random.rand(4,4)
# Out:
# array([[0.03086672, 0.66658204, 0.14819184, 0.75946933],
#        [0.01545589, 0.98573482, 0.83768102, 0.69235696],
#        [0.21402517, 0.20479689, 0.17978292, 0.08964317],
#        [0.93824079, 0.93700257, 0.3921378 , 0.93996918]])

# %% [markdown]
# 2. Create a random 100000x1 array from the same exponential distribution and visualize the
# distribution histogram along with uniform and normal distributions. Use the code given
# below and do the necessary changes. Change the number of bins and the plot view to make
# the visualization better.

# %%
import matplotlib.pyplot as plt 

# Generate 100000 samples
exp_data = np.random.exponential(scale=1.0, size=100000)
uniform_data = np.random.rand(100000)
normal_data = np.random.randn(100000)

# Plot all three distributions
plt.hist(exp_data, density=True, bins=200, histtype="step", color="red", label="Exponential")
plt.hist(uniform_data, density=True, bins=100, histtype="step", color="blue", label="Uniform")
plt.hist(normal_data, density=True, bins=100, histtype="step", color="green", label="Normal")

plt.axis([-2, 8, 0, 1.2])
plt.legend(loc="upper right")
plt.title("Random Distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Using matplotlib, plot the Z = X**2 + Y**2 in a 3D plot. Limit the x and y values to [-5, 5].

# %%
from mpl_toolkits.mplot3d import Axes3D

# Generate x and y values
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

Z = X**2 + Y**2

# Create 3D plot
figr = plt.figure(figsize=(10,7))
ax = figr.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(X,Y,Z, cmap='viridis')

# Labels and title
ax.set_title("3D Plot of Z = X² + Y²")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")

# Show plot
plt.show()

# %% [markdown]
# 4. Calculate the pearson standard coefficient and spearman rank correlation for the [HP,
# Attack, Defense, Sp. Ark, Sp. Def, Speed] features in the seaborn tutorial.ipynb. Visualize the
# results using heatmaps. Make sure the values are displaced in the heatmap as well.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Download the dataset
# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv

# Load the dataset
df = pd.read_csv("Pokemon.csv", encoding="latin1")

# Select relevant numeric features
features = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
data = df[features].dropna()

# Correlation matrices
pearson_corr = data.corr(method='pearson')
spearman_corr = data.corr(method='spearman')

# Heatmaps
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', fmt=".2f", ax=axes[0])
axes[0].set_title("Pearson Correlation")

sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', fmt=".2f", ax=axes[1])
axes[1].set_title("Spearman Correlation")

plt.tight_layout()
plt.show()
